# %% [markdown]
# <a href="https://colab.research.google.com/github/CM-MN/UnderstandingDeepLearning/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-yq2vwvxi
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-yq2vwvxi
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c9d10fb6bbeddf7b0eabc555a90a27b5a75ad52bf49ee656fd10913b5475e1ed
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r675mkgp/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
    nn.Linear(D_i, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_k),
    nn.ReLU(),
    nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.563974, train error 61.90,  test loss 1.664969, test error 68.60
# Epoch     1, train loss 1.319223, train error 48.85,  test loss 1.467358, test error 58.30
# Epoch     2, train loss 1.134939, train error 41.38,  test loss 1.351939, test error 54.50
# Epoch     3, train loss 1.008313, train error 37.00,  test loss 1.246223, test error 49.20
# Epoch     4, train loss 0.870341, train error 30.28,  test loss 1.184601, test error 46.30
# Epoch     5, train loss 0.817385, train error 29.30,  test loss 1.192801, test error 44.90
# Epoch     6, train loss 0.707485, train error 24.57,  test loss 1.119954, test error 42.40
# Epoch     7, train loss 0.666832, train error 24.32,  test loss 1.131476, test error 41.80
# Epoch     8, train loss 0.554772, train error 18.82,  test loss 1.091172, test error 40.20
# Epoch     9, train loss 0.541192, train error 19.85,  test loss 1.131779, test error 41.90
# Epoch    10, train loss 0.403563, train error 12.18,  test loss 1.042248, test error 38.90
# Epoch    11, train loss 0.362170, train error 9.60,  test loss 1.050160, test error 38.10
# Epoch    12, train loss 0.335284, train error 9.00,  test loss 1.067768, test error 37.50
# Epoch    13, train loss 0.304100, train error 8.10,  test loss 1.066409, test error 37.80
# Epoch    14, train loss 0.278499, train error 7.00,  test loss 1.112256, test error 38.10
# Epoch    15, train loss 0.272787, train error 7.85,  test loss 1.101706, test error 38.30
# Epoch    16, train loss 0.235277, train error 5.22,  test loss 1.107792, test error 38.10
# Epoch    17, train loss 0.220738, train error 5.35,  test loss 1.119400, test error 37.30
# Epoch    18, train loss 0.189300, train error 3.53,  test loss 1.167247, test error 37.60
# Epoch    19, train loss 0.188106, train error 4.05,  test loss 1.182284, test error 38.30
# Epoch    20, train loss 0.149108, train error 1.88,  test loss 1.177043, test error 37.00
# Epoch    21, train loss 0.133635, train error 1.18,  test loss 1.177753, test error 37.30
# Epoch    22, train loss 0.128946, train error 1.28,  test loss 1.186155, test error 37.40
# Epoch    23, train loss 0.120127, train error 0.97,  test loss 1.193887, test error 37.00
# Epoch    24, train loss 0.117372, train error 0.85,  test loss 1.213904, test error 37.30
# Epoch    25, train loss 0.108283, train error 0.55,  test loss 1.216837, test error 37.20
# Epoch    26, train loss 0.101727, train error 0.40,  test loss 1.217713, test error 37.20
# Epoch    27, train loss 0.098435, train error 0.55,  test loss 1.243515, test error 37.40
# Epoch    28, train loss 0.093215, train error 0.30,  test loss 1.250805, test error 37.30
# Epoch    29, train loss 0.087398, train error 0.35,  test loss 1.268332, test error 37.60
# Epoch    30, train loss 0.083403, train error 0.20,  test loss 1.266539, test error 37.50
# Epoch    31, train loss 0.081027, train error 0.20,  test loss 1.273593, test error 37.70
# Epoch    32, train loss 0.079261, train error 0.15,  test loss 1.281321, test error 37.50
# Epoch    33, train loss 0.077568, train error 0.18,  test loss 1.287386, test error 37.00
# Epoch    34, train loss 0.075475, train error 0.10,  test loss 1.291732, test error 37.50
# Epoch    35, train loss 0.073886, train error 0.15,  test loss 1.290712, test error 38.00
# Epoch    36, train loss 0.072168, train error 0.18,  test loss 1.304187, test error 37.70
# Epoch    37, train loss 0.070309, train error 0.12,  test loss 1.309030, test error 37.00
# Epoch    38, train loss 0.068648, train error 0.12,  test loss 1.314200, test error 37.30
# Epoch    39, train loss 0.067432, train error 0.15,  test loss 1.322927, test error 37.20
# Epoch    40, train loss 0.066179, train error 0.07,  test loss 1.321363, test error 36.90
# Epoch    41, train loss 0.065287, train error 0.10,  test loss 1.320583, test error 37.10
# Epoch    42, train loss 0.064593, train error 0.10,  test loss 1.324418, test error 37.20
# Epoch    43, train loss 0.063947, train error 0.10,  test loss 1.325058, test error 37.40
# Epoch    44, train loss 0.063200, train error 0.10,  test loss 1.329609, test error 37.20
# Epoch    45, train loss 0.063221, train error 0.07,  test loss 1.333940, test error 36.90
# Epoch    46, train loss 0.061964, train error 0.05,  test loss 1.334981, test error 37.40
# Epoch    47, train loss 0.061399, train error 0.10,  test loss 1.336794, test error 37.30
# Epoch    48, train loss 0.060611, train error 0.07,  test loss 1.339653, test error 37.10
# Epoch    49, train loss 0.059928, train error 0.05,  test loss 1.340950, test error 36.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
