# %% [markdown]
# <a href="https://colab.research.google.com/github/CM-MN/UnderstandingDeepLearning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-8uk34a6k
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-8uk34a6k
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=66fc73aa9bed56f81815246269d66da8effcebacc78f9399565e56436e71c522
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ux037xni/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303398, train error 89.78,  test loss 2.303071, test error 90.18
# Epoch   100, train loss 1.868785, train error 70.72,  test loss 1.715855, test error 68.55
# Epoch   200, train loss 1.859201, train error 71.03,  test loss 1.700132, test error 69.18
# Epoch   300, train loss 1.853671, train error 69.97,  test loss 1.704601, test error 68.97
# Epoch   400, train loss 1.851045, train error 70.12,  test loss 1.707931, test error 68.97
# Epoch   500, train loss 1.850126, train error 69.90,  test loss 1.713307, test error 68.20
# Epoch   600, train loss 1.853228, train error 70.22,  test loss 1.710945, test error 68.68
# Epoch   700, train loss 1.847673, train error 69.55,  test loss 1.705032, test error 68.00
# Epoch   800, train loss 1.849505, train error 69.68,  test loss 1.704527, test error 68.85
# Epoch   900, train loss 1.848583, train error 69.72,  test loss 1.711699, test error 67.97
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301756, train error 88.90,  test loss 2.303961, test error 89.55
# Epoch   100, train loss 1.816140, train error 68.78,  test loss 1.671010, test error 64.88
# Epoch   200, train loss 1.770426, train error 66.70,  test loss 1.636782, test error 66.15
# Epoch   300, train loss 1.736615, train error 64.28,  test loss 1.581701, test error 61.35
# Epoch   400, train loss 1.715240, train error 62.88,  test loss 1.518551, test error 59.38
# Epoch   500, train loss 1.702804, train error 62.30,  test loss 1.509920, test error 58.55
# Epoch   600, train loss 1.697798, train error 62.40,  test loss 1.500842, test error 58.33
# Epoch   700, train loss 1.694856, train error 62.33,  test loss 1.501810, test error 58.38
# Epoch   800, train loss 1.695077, train error 62.10,  test loss 1.503352, test error 57.75
# Epoch   900, train loss 1.694352, train error 61.97,  test loss 1.499613, test error 57.70
# Training model with   6 hidden variables
# Epoch     0, train loss 2.227270, train error 84.20,  test loss 2.196397, test error 83.95
# Epoch   100, train loss 1.684697, train error 60.03,  test loss 1.539014, test error 60.08
# Epoch   200, train loss 1.643638, train error 58.80,  test loss 1.486959, test error 57.42
# Epoch   300, train loss 1.626464, train error 58.58,  test loss 1.470117, test error 55.78
# Epoch   400, train loss 1.617536, train error 57.42,  test loss 1.455846, test error 55.97
# Epoch   500, train loss 1.593319, train error 56.80,  test loss 1.430165, test error 54.72
# Epoch   600, train loss 1.584698, train error 57.22,  test loss 1.419918, test error 54.38
# Epoch   700, train loss 1.580592, train error 55.85,  test loss 1.418362, test error 54.58
# Epoch   800, train loss 1.579764, train error 56.28,  test loss 1.425857, test error 54.72
# Epoch   900, train loss 1.575325, train error 55.72,  test loss 1.430660, test error 55.25
# Training model with   8 hidden variables
# Epoch     0, train loss 2.302666, train error 88.93,  test loss 2.320774, test error 90.10
# Epoch   100, train loss 1.585905, train error 55.38,  test loss 1.415298, test error 53.05
# Epoch   200, train loss 1.493964, train error 50.22,  test loss 1.290491, test error 48.45
# Epoch   300, train loss 1.474672, train error 50.22,  test loss 1.287065, test error 47.60
# Epoch   400, train loss 1.468967, train error 49.80,  test loss 1.278471, test error 47.28
# Epoch   500, train loss 1.458338, train error 49.60,  test loss 1.280469, test error 47.42
# Epoch   600, train loss 1.460630, train error 49.83,  test loss 1.288324, test error 47.40
# Epoch   700, train loss 1.450145, train error 49.42,  test loss 1.278088, test error 48.08
# Epoch   800, train loss 1.455449, train error 50.03,  test loss 1.292737, test error 48.17
# Epoch   900, train loss 1.447528, train error 49.72,  test loss 1.284273, test error 47.62
# Training model with  10 hidden variables
# Epoch     0, train loss 2.225881, train error 82.85,  test loss 2.213989, test error 83.80
# Epoch   100, train loss 1.481395, train error 49.67,  test loss 1.323758, test error 48.53
# Epoch   200, train loss 1.410397, train error 47.50,  test loss 1.286471, test error 47.28
# Epoch   300, train loss 1.384414, train error 46.53,  test loss 1.286034, test error 47.50
# Epoch   400, train loss 1.373844, train error 45.92,  test loss 1.303692, test error 48.05
# Epoch   500, train loss 1.369078, train error 45.53,  test loss 1.290050, test error 47.38
# Epoch   600, train loss 1.363804, train error 46.20,  test loss 1.296329, test error 46.72
# Epoch   700, train loss 1.362070, train error 45.88,  test loss 1.308746, test error 47.35
# Epoch   800, train loss 1.352512, train error 45.40,  test loss 1.305453, test error 46.92
# Epoch   900, train loss 1.359435, train error 45.78,  test loss 1.317049, test error 47.78
# Training model with  14 hidden variables
# Epoch     0, train loss 2.226879, train error 83.22,  test loss 2.237556, test error 82.55
# Epoch   100, train loss 1.473559, train error 51.10,  test loss 1.383495, test error 51.92
# Epoch   200, train loss 1.385538, train error 47.20,  test loss 1.363526, test error 50.40
# Epoch   300, train loss 1.347266, train error 44.97,  test loss 1.365635, test error 49.85
# Epoch   400, train loss 1.325567, train error 44.03,  test loss 1.382875, test error 50.08
# Epoch   500, train loss 1.313676, train error 44.28,  test loss 1.413034, test error 50.70
# Epoch   600, train loss 1.302770, train error 44.17,  test loss 1.419437, test error 50.33
# Epoch   700, train loss 1.294739, train error 44.05,  test loss 1.448766, test error 50.53
# Epoch   800, train loss 1.284784, train error 43.70,  test loss 1.472394, test error 51.50
# Epoch   900, train loss 1.277693, train error 43.80,  test loss 1.512661, test error 51.78
# Training model with  18 hidden variables
# Epoch     0, train loss 2.201686, train error 80.45,  test loss 2.189650, test error 80.80
# Epoch   100, train loss 1.336780, train error 44.55,  test loss 1.293608, test error 47.78
# Epoch   200, train loss 1.230645, train error 40.72,  test loss 1.295302, test error 47.12
# Epoch   300, train loss 1.177866, train error 38.83,  test loss 1.342069, test error 47.53
# Epoch   400, train loss 1.147190, train error 38.15,  test loss 1.388437, test error 48.03
# Epoch   500, train loss 1.138459, train error 38.62,  test loss 1.437708, test error 48.83
# Epoch   600, train loss 1.122329, train error 36.95,  test loss 1.447870, test error 48.50
# Epoch   700, train loss 1.121028, train error 37.38,  test loss 1.473836, test error 48.28
# Epoch   800, train loss 1.107114, train error 37.12,  test loss 1.494902, test error 48.75
# Epoch   900, train loss 1.106755, train error 37.00,  test loss 1.537094, test error 48.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.182792, train error 80.20,  test loss 2.144711, test error 79.43
# Epoch   100, train loss 1.277665, train error 42.67,  test loss 1.302738, test error 48.15
# Epoch   200, train loss 1.146815, train error 38.17,  test loss 1.391401, test error 49.22
# Epoch   300, train loss 1.094059, train error 37.50,  test loss 1.483177, test error 51.40
# Epoch   400, train loss 1.059776, train error 36.53,  test loss 1.557266, test error 52.00
# Epoch   500, train loss 1.029916, train error 35.15,  test loss 1.608768, test error 52.50
# Epoch   600, train loss 1.027570, train error 35.32,  test loss 1.698357, test error 53.45
# Epoch   700, train loss 1.001676, train error 34.57,  test loss 1.734972, test error 54.03
# Epoch   800, train loss 0.993910, train error 33.88,  test loss 1.768436, test error 53.95
# Epoch   900, train loss 0.984188, train error 33.82,  test loss 1.805653, test error 54.03
# Training model with  26 hidden variables
# Epoch     0, train loss 2.151187, train error 78.75,  test loss 2.104041, test error 77.45
# Epoch   100, train loss 1.172255, train error 37.47,  test loss 1.304802, test error 47.85
# Epoch   200, train loss 1.007103, train error 33.68,  test loss 1.432459, test error 49.28
# Epoch   300, train loss 0.949935, train error 32.85,  test loss 1.610727, test error 51.42
# Epoch   400, train loss 0.902677, train error 30.78,  test loss 1.701670, test error 50.85
# Epoch   500, train loss 0.869555, train error 29.95,  test loss 1.788021, test error 52.25
# Epoch   600, train loss 0.863306, train error 30.25,  test loss 1.852311, test error 53.03
# Epoch   700, train loss 0.844527, train error 29.62,  test loss 1.879870, test error 52.08
# Epoch   800, train loss 0.848009, train error 29.38,  test loss 1.984979, test error 53.10
# Epoch   900, train loss 0.840548, train error 29.45,  test loss 2.001984, test error 52.60
# Training model with  30 hidden variables
# Epoch     0, train loss 2.107097, train error 78.72,  test loss 2.049664, test error 77.95
# Epoch   100, train loss 1.146541, train error 38.88,  test loss 1.355954, test error 50.12
# Epoch   200, train loss 0.954729, train error 32.10,  test loss 1.545183, test error 53.00
# Epoch   300, train loss 0.870948, train error 29.70,  test loss 1.745855, test error 52.95
# Epoch   400, train loss 0.813507, train error 28.62,  test loss 1.894053, test error 54.08
# Epoch   500, train loss 0.772097, train error 26.20,  test loss 2.039896, test error 55.40
# Epoch   600, train loss 0.765645, train error 26.25,  test loss 2.193393, test error 54.38
# Epoch   700, train loss 0.709365, train error 24.82,  test loss 2.307539, test error 55.17
# Epoch   800, train loss 0.684710, train error 23.32,  test loss 2.438815, test error 55.75
# Epoch   900, train loss 0.679690, train error 23.40,  test loss 2.582375, test error 56.45
# Training model with  35 hidden variables
# Epoch     0, train loss 2.123021, train error 79.93,  test loss 2.073708, test error 79.93
# Epoch   100, train loss 1.049295, train error 35.05,  test loss 1.434408, test error 50.42
# Epoch   200, train loss 0.835435, train error 28.15,  test loss 1.702293, test error 51.70
# Epoch   300, train loss 0.700905, train error 24.03,  test loss 2.071808, test error 54.35
# Epoch   400, train loss 0.617703, train error 20.82,  test loss 2.314696, test error 53.90
# Epoch   500, train loss 0.576858, train error 19.38,  test loss 2.612859, test error 54.78
# Epoch   600, train loss 0.512966, train error 16.95,  test loss 2.939218, test error 55.40
# Epoch   700, train loss 0.485914, train error 16.75,  test loss 3.205281, test error 56.88
# Epoch   800, train loss 0.488065, train error 17.05,  test loss 3.494288, test error 56.90
# Epoch   900, train loss 0.441697, train error 15.22,  test loss 3.717213, test error 57.00
# Training model with  40 hidden variables
# Epoch     0, train loss 2.126674, train error 79.82,  test loss 2.078697, test error 78.12
# Epoch   100, train loss 0.909637, train error 29.93,  test loss 1.414731, test error 48.00
# Epoch   200, train loss 0.646587, train error 21.60,  test loss 1.888481, test error 52.60
# Epoch   300, train loss 0.514825, train error 17.28,  test loss 2.504414, test error 54.08
# Epoch   400, train loss 0.452009, train error 16.53,  test loss 3.244448, test error 55.38
# Epoch   500, train loss 0.380652, train error 13.60,  test loss 3.891262, test error 55.92
# Epoch   600, train loss 0.355768, train error 12.70,  test loss 4.638960, test error 56.90
# Epoch   700, train loss 0.364377, train error 13.20,  test loss 5.201674, test error 57.22
# Epoch   800, train loss 0.276187, train error 10.40,  test loss 5.752500, test error 56.70
# Epoch   900, train loss 0.227811, train error 8.03,  test loss 6.329616, test error 57.17
# Training model with  45 hidden variables
# Epoch     0, train loss 2.090163, train error 77.80,  test loss 2.045421, test error 78.10
# Epoch   100, train loss 0.826443, train error 26.47,  test loss 1.489884, test error 51.05
# Epoch   200, train loss 0.499943, train error 15.85,  test loss 2.262137, test error 53.85
# Epoch   300, train loss 0.309776, train error 9.30,  test loss 3.268908, test error 55.00
# Epoch   400, train loss 0.220959, train error 6.85,  test loss 4.606864, test error 56.08
# Epoch   500, train loss 0.181330, train error 6.12,  test loss 5.837105, test error 56.28
# Epoch   600, train loss 0.186755, train error 6.80,  test loss 7.290798, test error 56.55
# Epoch   700, train loss 0.030036, train error 0.28,  test loss 8.127745, test error 57.08
# Epoch   800, train loss 0.011087, train error 0.00,  test loss 9.094617, test error 57.70
# Epoch   900, train loss 0.007660, train error 0.00,  test loss 9.739343, test error 57.75
# Training model with  50 hidden variables
# Epoch     0, train loss 2.063395, train error 76.57,  test loss 2.003351, test error 75.82
# Epoch   100, train loss 0.742159, train error 23.55,  test loss 1.635638, test error 53.62
# Epoch   200, train loss 0.341112, train error 10.00,  test loss 2.613977, test error 54.55
# Epoch   300, train loss 0.189395, train error 5.32,  test loss 4.095027, test error 55.85
# Epoch   400, train loss 0.032905, train error 0.03,  test loss 5.722385, test error 56.38
# Epoch   500, train loss 0.014325, train error 0.00,  test loss 6.800605, test error 56.72
# Epoch   600, train loss 0.009066, train error 0.00,  test loss 7.483852, test error 56.33
# Epoch   700, train loss 0.006266, train error 0.00,  test loss 7.993904, test error 56.67
# Epoch   800, train loss 0.004795, train error 0.00,  test loss 8.397200, test error 56.80
# Epoch   900, train loss 0.003859, train error 0.00,  test loss 8.739505, test error 56.80
# Training model with  55 hidden variables
# Epoch     0, train loss 2.067716, train error 76.60,  test loss 2.021353, test error 77.85
# Epoch   100, train loss 0.619590, train error 19.10,  test loss 1.714869, test error 51.55
# Epoch   200, train loss 0.189946, train error 3.57,  test loss 3.188500, test error 54.28
# Epoch   300, train loss 0.036153, train error 0.03,  test loss 4.899746, test error 55.03
# Epoch   400, train loss 0.014028, train error 0.00,  test loss 5.891232, test error 55.70
# Epoch   500, train loss 0.008069, train error 0.00,  test loss 6.503788, test error 55.60
# Epoch   600, train loss 0.005602, train error 0.00,  test loss 6.950532, test error 55.55
# Epoch   700, train loss 0.004211, train error 0.00,  test loss 7.287485, test error 55.45
# Epoch   800, train loss 0.003341, train error 0.00,  test loss 7.567491, test error 55.30
# Epoch   900, train loss 0.002746, train error 0.00,  test loss 7.803298, test error 55.38
# Training model with  60 hidden variables
# Epoch     0, train loss 2.096313, train error 77.88,  test loss 2.057169, test error 76.57
# Epoch   100, train loss 0.483865, train error 13.18,  test loss 1.800071, test error 51.03
# Epoch   200, train loss 0.082655, train error 0.43,  test loss 3.590312, test error 52.88
# Epoch   300, train loss 0.016587, train error 0.00,  test loss 4.779679, test error 53.47
# Epoch   400, train loss 0.008429, train error 0.00,  test loss 5.402400, test error 53.62
# Epoch   500, train loss 0.005447, train error 0.00,  test loss 5.818806, test error 53.67
# Epoch   600, train loss 0.003947, train error 0.00,  test loss 6.133169, test error 53.75
# Epoch   700, train loss 0.003052, train error 0.00,  test loss 6.381147, test error 53.70
# Epoch   800, train loss 0.002464, train error 0.00,  test loss 6.590529, test error 53.75
# Epoch   900, train loss 0.002059, train error 0.00,  test loss 6.771277, test error 53.62
# Training model with  70 hidden variables
# Epoch     0, train loss 2.043953, train error 76.57,  test loss 1.989165, test error 75.32
# Epoch   100, train loss 0.366653, train error 8.85,  test loss 1.895678, test error 52.10
# Epoch   200, train loss 0.033412, train error 0.00,  test loss 3.538260, test error 53.83
# Epoch   300, train loss 0.010858, train error 0.00,  test loss 4.310667, test error 54.00
# Epoch   400, train loss 0.006087, train error 0.00,  test loss 4.754790, test error 53.92
# Epoch   500, train loss 0.004079, train error 0.00,  test loss 5.055645, test error 53.97
# Epoch   600, train loss 0.003012, train error 0.00,  test loss 5.294044, test error 54.08
# Epoch   700, train loss 0.002356, train error 0.00,  test loss 5.483756, test error 54.00
# Epoch   800, train loss 0.001926, train error 0.00,  test loss 5.641967, test error 54.17
# Epoch   900, train loss 0.001618, train error 0.00,  test loss 5.778185, test error 54.12
# Training model with  80 hidden variables
# Epoch     0, train loss 2.023893, train error 74.55,  test loss 1.990799, test error 74.97
# Epoch   100, train loss 0.242368, train error 4.62,  test loss 2.115490, test error 51.30
# Epoch   200, train loss 0.019990, train error 0.00,  test loss 3.398900, test error 51.62
# Epoch   300, train loss 0.008128, train error 0.00,  test loss 3.943129, test error 51.62
# Epoch   400, train loss 0.004804, train error 0.00,  test loss 4.274009, test error 51.65
# Epoch   500, train loss 0.003329, train error 0.00,  test loss 4.510851, test error 51.65
# Epoch   600, train loss 0.002494, train error 0.00,  test loss 4.693720, test error 51.70
# Epoch   700, train loss 0.001979, train error 0.00,  test loss 4.843654, test error 51.88
# Epoch   800, train loss 0.001629, train error 0.00,  test loss 4.966900, test error 51.80
# Epoch   900, train loss 0.001377, train error 0.00,  test loss 5.073617, test error 51.83
# Training model with  90 hidden variables
# Epoch     0, train loss 2.021529, train error 75.43,  test loss 1.945967, test error 74.50
# Epoch   100, train loss 0.147198, train error 1.30,  test loss 2.088514, test error 50.50
# Epoch   200, train loss 0.015530, train error 0.00,  test loss 3.135139, test error 50.70
# Epoch   300, train loss 0.006822, train error 0.00,  test loss 3.571542, test error 51.10
# Epoch   400, train loss 0.004120, train error 0.00,  test loss 3.837417, test error 51.17
# Epoch   500, train loss 0.002895, train error 0.00,  test loss 4.028759, test error 51.25
# Epoch   600, train loss 0.002195, train error 0.00,  test loss 4.178273, test error 51.28
# Epoch   700, train loss 0.001753, train error 0.00,  test loss 4.301528, test error 51.28
# Epoch   800, train loss 0.001450, train error 0.00,  test loss 4.405499, test error 51.35
# Epoch   900, train loss 0.001230, train error 0.00,  test loss 4.496254, test error 51.38
# Training model with 100 hidden variables
# Epoch     0, train loss 1.993562, train error 75.12,  test loss 1.968205, test error 76.47
# Epoch   100, train loss 0.086017, train error 0.12,  test loss 2.197784, test error 50.78
# Epoch   200, train loss 0.012120, train error 0.00,  test loss 3.041291, test error 50.92
# Epoch   300, train loss 0.005600, train error 0.00,  test loss 3.399765, test error 50.83
# Epoch   400, train loss 0.003501, train error 0.00,  test loss 3.622592, test error 50.83
# Epoch   500, train loss 0.002492, train error 0.00,  test loss 3.785323, test error 51.03
# Epoch   600, train loss 0.001912, train error 0.00,  test loss 3.914242, test error 51.10
# Epoch   700, train loss 0.001536, train error 0.00,  test loss 4.021460, test error 51.25
# Epoch   800, train loss 0.001276, train error 0.00,  test loss 4.110720, test error 51.28
# Epoch   900, train loss 0.001087, train error 0.00,  test loss 4.189103, test error 51.30
# Training model with 120 hidden variables
# Epoch     0, train loss 1.959694, train error 72.70,  test loss 1.893143, test error 72.82
# Epoch   100, train loss 0.048619, train error 0.00,  test loss 2.163581, test error 49.88
# Epoch   200, train loss 0.009452, train error 0.00,  test loss 2.753561, test error 50.22
# Epoch   300, train loss 0.004673, train error 0.00,  test loss 3.016497, test error 50.12
# Epoch   400, train loss 0.002991, train error 0.00,  test loss 3.190252, test error 50.20
# Epoch   500, train loss 0.002161, train error 0.00,  test loss 3.316375, test error 50.42
# Epoch   600, train loss 0.001670, train error 0.00,  test loss 3.417176, test error 50.22
# Epoch   700, train loss 0.001352, train error 0.00,  test loss 3.500103, test error 50.25
# Epoch   800, train loss 0.001129, train error 0.00,  test loss 3.571311, test error 50.30
# Epoch   900, train loss 0.000965, train error 0.00,  test loss 3.633570, test error 50.30
# Training model with 140 hidden variables
# Epoch     0, train loss 1.954855, train error 72.15,  test loss 1.884382, test error 73.72
# Epoch   100, train loss 0.035565, train error 0.00,  test loss 2.239615, test error 50.35
# Epoch   200, train loss 0.007987, train error 0.00,  test loss 2.736052, test error 50.55
# Epoch   300, train loss 0.004126, train error 0.00,  test loss 2.979698, test error 50.40
# Epoch   400, train loss 0.002686, train error 0.00,  test loss 3.138456, test error 50.25
# Epoch   500, train loss 0.001957, train error 0.00,  test loss 3.257063, test error 50.20
# Epoch   600, train loss 0.001523, train error 0.00,  test loss 3.349856, test error 50.12
# Epoch   700, train loss 0.001237, train error 0.00,  test loss 3.427819, test error 50.15
# Epoch   800, train loss 0.001036, train error 0.00,  test loss 3.494045, test error 50.00
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.552048, test error 50.00
# Training model with 160 hidden variables
# Epoch     0, train loss 1.931767, train error 71.53,  test loss 1.892084, test error 71.50
# Epoch   100, train loss 0.028456, train error 0.00,  test loss 2.050921, test error 48.28
# Epoch   200, train loss 0.007157, train error 0.00,  test loss 2.448703, test error 48.80
# Epoch   300, train loss 0.003759, train error 0.00,  test loss 2.645505, test error 48.78
# Epoch   400, train loss 0.002467, train error 0.00,  test loss 2.776912, test error 48.92
# Epoch   500, train loss 0.001807, train error 0.00,  test loss 2.874292, test error 48.90
# Epoch   600, train loss 0.001411, train error 0.00,  test loss 2.952774, test error 48.72
# Epoch   700, train loss 0.001149, train error 0.00,  test loss 3.018365, test error 48.65
# Epoch   800, train loss 0.000964, train error 0.00,  test loss 3.073665, test error 48.65
# Epoch   900, train loss 0.000827, train error 0.00,  test loss 3.122783, test error 48.67
# Training model with 180 hidden variables
# Epoch     0, train loss 1.958432, train error 72.78,  test loss 1.900451, test error 74.75
# Epoch   100, train loss 0.024224, train error 0.00,  test loss 2.110023, test error 48.78
# Epoch   200, train loss 0.006583, train error 0.00,  test loss 2.473968, test error 48.67
# Epoch   300, train loss 0.003525, train error 0.00,  test loss 2.656312, test error 48.80
# Epoch   400, train loss 0.002339, train error 0.00,  test loss 2.779203, test error 48.85
# Epoch   500, train loss 0.001722, train error 0.00,  test loss 2.871491, test error 48.70
# Epoch   600, train loss 0.001350, train error 0.00,  test loss 2.945693, test error 48.67
# Epoch   700, train loss 0.001102, train error 0.00,  test loss 3.007287, test error 48.67
# Epoch   800, train loss 0.000927, train error 0.00,  test loss 3.060458, test error 48.67
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.107037, test error 48.62
# Training model with 200 hidden variables
# Epoch     0, train loss 1.948612, train error 71.72,  test loss 1.866179, test error 72.85
# Epoch   100, train loss 0.021469, train error 0.00,  test loss 2.061904, test error 48.47
# Epoch   200, train loss 0.006133, train error 0.00,  test loss 2.386197, test error 48.05
# Epoch   300, train loss 0.003337, train error 0.00,  test loss 2.553961, test error 48.22
# Epoch   400, train loss 0.002226, train error 0.00,  test loss 2.666640, test error 48.28
# Epoch   500, train loss 0.001645, train error 0.00,  test loss 2.752319, test error 48.22
# Epoch   600, train loss 0.001293, train error 0.00,  test loss 2.820139, test error 48.12
# Epoch   700, train loss 0.001058, train error 0.00,  test loss 2.877529, test error 48.10
# Epoch   800, train loss 0.000891, train error 0.00,  test loss 2.926393, test error 48.22
# Epoch   900, train loss 0.000767, train error 0.00,  test loss 2.969316, test error 48.22
# Training model with 250 hidden variables
# Epoch     0, train loss 1.864722, train error 67.18,  test loss 1.794658, test error 69.03
# Epoch   100, train loss 0.016888, train error 0.00,  test loss 1.851007, test error 46.62
# Epoch   200, train loss 0.005308, train error 0.00,  test loss 2.088831, test error 46.60
# Epoch   300, train loss 0.002953, train error 0.00,  test loss 2.215482, test error 46.45
# Epoch   400, train loss 0.001995, train error 0.00,  test loss 2.301277, test error 46.62
# Epoch   500, train loss 0.001486, train error 0.00,  test loss 2.365931, test error 46.45
# Epoch   600, train loss 0.001173, train error 0.00,  test loss 2.419071, test error 46.53
# Epoch   700, train loss 0.000963, train error 0.00,  test loss 2.463067, test error 46.38
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.500809, test error 46.20
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.534484, test error 46.17
# Training model with 300 hidden variables
# Epoch     0, train loss 1.877873, train error 68.05,  test loss 1.806905, test error 68.72
# Epoch   100, train loss 0.014637, train error 0.00,  test loss 1.837818, test error 45.75
# Epoch   200, train loss 0.004846, train error 0.00,  test loss 2.049567, test error 45.67
# Epoch   300, train loss 0.002753, train error 0.00,  test loss 2.168187, test error 45.60
# Epoch   400, train loss 0.001873, train error 0.00,  test loss 2.247616, test error 45.60
# Epoch   500, train loss 0.001401, train error 0.00,  test loss 2.309154, test error 45.45
# Epoch   600, train loss 0.001110, train error 0.00,  test loss 2.359227, test error 45.45
# Epoch   700, train loss 0.000913, train error 0.00,  test loss 2.400835, test error 45.50
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.436991, test error 45.50
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.468607, test error 45.40
# Training model with 400 hidden variables
# Epoch     0, train loss 1.840908, train error 66.03,  test loss 1.779458, test error 70.03
# Epoch   100, train loss 0.011556, train error 0.00,  test loss 1.800622, test error 47.20
# Epoch   200, train loss 0.004112, train error 0.00,  test loss 1.981810, test error 47.28
# Epoch   300, train loss 0.002385, train error 0.00,  test loss 2.082887, test error 47.20
# Epoch   400, train loss 0.001645, train error 0.00,  test loss 2.152672, test error 47.08
# Epoch   500, train loss 0.001240, train error 0.00,  test loss 2.205274, test error 47.00
# Epoch   600, train loss 0.000987, train error 0.00,  test loss 2.248809, test error 47.12
# Epoch   700, train loss 0.000816, train error 0.00,  test loss 2.285683, test error 47.17
# Epoch   800, train loss 0.000693, train error 0.00,  test loss 2.317127, test error 47.20
# Epoch   900, train loss 0.000600, train error 0.00,  test loss 2.345097, test error 47.20

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
